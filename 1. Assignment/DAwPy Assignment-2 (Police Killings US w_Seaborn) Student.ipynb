# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv("PoliceKillingsUS.csv", encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill["manner_of_death"].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x="gender", y="age", data=kill, hue="manner_of_death");

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(10,5))
sns.swarmplot(x="gender", y="age", data=kill, hue="manner_of_death");

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
kill.city.value_counts().head(12)
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
# with seaborn barplot
plt.figure(figsize=(8,5))

xlabel=kill["city"].value_counts().head(12).index
ylabel=kill["city"].value_counts().head(12).values

plt.title("Most Dangerous Cities", fontsize=14, color="blue")
sns.barplot(x=xlabel, y=ylabel, data=kill)
plt.xticks(rotation=45)

plt.show()

# %%
# with seaborn countplot
plt.figure(figsize=(8,5))

xlabel=kill["city"].value_counts().head(12).index

sns.countplot(x="city", data=kill, order=xlabel)
plt.xticks(rotation=45)
plt.title("Most Dangerous Cities", fontsize=14, color="blue")

plt.show()

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
kill.state.value_counts().head(20)
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
plt.figure(figsize=(8,5))

xlabel=kill["state"].value_counts().head(20).index
ylabel=kill["state"].value_counts().head(20).values

plt.title("Most Dangerous Cities", fontsize=14, color="blue")
sns.barplot(x=xlabel, y=ylabel, data=kill)
plt.xticks(rotation=45)

plt.show()

# %%
# with seaborn countplot

plt.figure(figsize=(8,5))

xlabel=kill["state"].value_counts().head(20).index

sns.countplot(x="state", data=kill, order=xlabel)
plt.xticks(rotation=45)
plt.title("Most Dangerous States", fontsize=14, color="blue")

plt.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts(dropna=False)
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
sns.countplot(x="signs_of_mental_illness", data=kill);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.threat_level.value_counts()
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot(x="threat_level", data=kill);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
sns.countplot(x="flee", data=kill);
